# %% [markdown]
# ## Contested Zones in Serie A

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as path_effects
import matplotlib.font_manager as fm
import matplotlib.colors as mcolors
from matplotlib import cm
from highlight_text import HighlightText, fig_text, ax_text
from mplsoccer import Pitch

from PIL import Image
import urllib
import os

# %%
font_path = "../assets/fonts"
for x in os.listdir(font_path):
    for y in os.listdir(f"{font_path}/{x}"):
        if y.split(".")[-1] == "otf":
            fm.fontManager.addfont(f"{font_path}/{x}/{y}")
            try:
                fm.FontProperties(weight=y.split("-")[-1].split(".")[0].lower(), fname=y.split("-")[0])
            except Exception:
                continue

plt.style.use("../assets/stylesheets/soc_base.mplstyle")
plt.rcParams['font.family'] = 'Nippo'

# %%
data = pd.read_csv('data/10242022_seriea_touches.csv', index_col=0)
data
# Out:
#      team_id      team  zone  perc_for  perc_against    classed  self_rank  \
# 0        120     Milan     1  0.591837      0.408163       team   0.209677
# 1        120     Milan     2  0.563518      0.436482       team   0.580645
# 2        120     Milan     3  0.549107      0.450893  contested   0.806452
# 3        120     Milan     4  0.525562      0.474438  contested   0.870968
# 4        120     Milan     5  0.460759      0.539241  contested   0.629032
# ..       ...       ...   ...       ...           ...        ...        ...
# 595     2182  Sassuolo    26  0.522796      0.477204  contested   0.580645
# 596     2182  Sassuolo    27  0.503448      0.496552  contested   0.870968
# 597     2182  Sassuolo    28  0.571739      0.428261       team   0.935484
# 598     2182  Sassuolo    29  0.492492      0.507508  contested   0.451613
# 599     2182  Sassuolo    30  0.454545      0.545455  contested   0.080645
#
#      opp_rank  biv_rank     season
# 0    0.129032         1  2021/2022
# 1    0.451613         8  2021/2022
# 2    0.806452         9  2021/2022
# 3    0.935484         9  2021/2022
# 4    0.870968         9  2021/2022
# ..        ...       ...        ...
# 595  0.548387         8  2021/2022
# 596  0.870968         9  2021/2022
# 597  0.774194         9  2021/2022
# 598  0.612903         6  2021/2022
# 599  0.161290         1  2021/2022
#
# [600 rows x 10 columns]

# %% [markdown]
# ## Adjusting the Pitch

# %%
fig = plt.figure(figsize = (4,4), dpi = 200)
ax = plt.subplot(111)
pitch = Pitch(
    pitch_type='uefa',
    half=False,
    axis=True, 
    label=True, 
    tick=True,
    goal_type='box',
    positional=True
)
pitch.draw(ax = ax)

# Here we can get the positional dimensions
pos_x = pitch.dim.positional_x
pos_y = pitch.dim.positional_y

# We test the dimensions with the labels we got from the Analyst
counter = 1

for index_y, y in enumerate(pos_y):
    for index_x, x in enumerate(pos_x):
        try:
            label_y = (pos_y[index_y] + pos_y[index_y + 1])/2
            label_x = (pos_x[index_x] + pos_x[index_x + 1])/2
        except:
            continue
        ax.annotate(
            xy=(label_x, label_y),
            text=counter,
            ha='center',
            va='center'
        )
        counter += 1

# %% [markdown]
# ## A function to generate plot for any team

# %%
test_df = data[data['team'] == 'Napoli']
test_df.head()
# Out:
#      team_id    team  zone  perc_for  perc_against    classed  self_rank  \
# 360      459  Napoli     1  0.698413      0.301587       team   0.225806
# 361      459  Napoli     2  0.551155      0.448845       team   0.451613
# 362      459  Napoli     3  0.554622      0.445378       team   0.548387
# 363      459  Napoli     4  0.594737      0.405263       team   0.645161
# 364      459  Napoli     5  0.517857      0.482143  contested   0.516129
#
#      opp_rank  biv_rank     season
# 360  0.161290         1  2021/2022
# 361  0.532258         5  2021/2022
# 362  0.677419         6  2021/2022
# 363  0.629032         9  2021/2022
# 364  0.790323         6  2021/2022

# %%
def plot_zone_dominance(ax, team_id):
    filtered_df = data[data['team_id'] == team_id].copy()
    pitch = Pitch(
        pitch_type='uefa',
        goal_type='box',
        linewidth=1.1,
        line_color='black',
        pad_top=10,
        corner_arcs=True
    )
    pitch.draw(ax = ax)

    # Here we can get the positional dimensions
    pos_x = pitch.dim.positional_x
    pos_y = pitch.dim.positional_y

    # We test the dimensions with the labels we got from the Analyst
    counter = 1
    filtered_df['zone'] = filtered_df['zone'].astype(int)
    for index_y, y in enumerate(pos_y):
        for index_x, x in enumerate(pos_x):
            try:
                label_y = (pos_y[index_y] + pos_y[index_y + 1])/2
                label_x = (pos_x[index_x] + pos_x[index_x + 1])/2
                lower_y = pos_y[index_y]
                lower_x = pos_x[index_x]
                upper_y = pos_y[index_y + 1]
                upper_x = pos_x[index_x + 1]
            except:
                continue
            data_point = filtered_df[filtered_df['zone'] == counter]['perc_for'].iloc[0]
            '''if data_point > .55:
            color = '#3E5641'
            elif data_point < .45:
                color = '#461220'
            else:
                color = '#FCB9B2'
            '''
            if data_point > .55:
                color = '#117733'
            elif data_point < .45:
                color = '#882255'
            else:
                color = '84184E'#'#CC6677'
            ax.fill_between(
                x=[lower_x, upper_x],
                y1=lower_y,
                y2=upper_y,
                color=color,
                zorder=0,
                alpha=0.75,
                ec='None'
            )
            counter += 1
    ax.annotate(
        xy=(pos_x[0]*1.15, pos_y[-1]*1.1),
        text=f"{filtered_df['team'].iloc[0].upper()}",
        size=9,
        color='black',
        ha='left',
        va='center',
        weight='bold',
    )

    for x in pos_x[1:-1]:
        ax.plot([x,x], [pos_y[0], pos_y[-1]], color='#000000', ls='dashed', zorder=0, lw=0.3)
    for y in pos_y[1:-1]:
        ax.plot([pos_x[0], pos_x[-1]], [y,y], color='#000000', ls='dashed', zorder=0, lw=0.3)
    
    return ax

# %%
fig = plt.figure(figsize = (4,4), dpi = 200)
ax = plt.subplot(111)
plot_zone_dominance(ax, 459)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 fig = plt.figure(figsize = (4,4), dpi = 200)
#       2 ax = plt.subplot(111)
# ----> 3 plot_zone_dominance(ax, 459)
#
# Cell In[40], line 45, in plot_zone_dominance(ax, team_id)
#      43         else:
#      44             color = '84184E'#'#CC6677'
# ---> 45         ax.fill_between(
#      46             x=[lower_x, upper_x],
#      47             y1=lower_y,
#      48             y2=upper_y,
#      49             color=color,
#      50             zorder=0,
#      51             alpha=0.75,
#      52             ec='None'
#      53         )
#      54         counter += 1
#      55 ax.annotate(
#      56     xy=(pos_x[0]*1.15, pos_y[-1]*1.1),
#      57     text=f"{filtered_df['team'].iloc[0].upper()}",
#    (...)
#      62     weight='bold',
#      63 )
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\axes\_axes.py:5252, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5250 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5251                  step=None, **kwargs):
# -> 5252     return self._fill_between_x_or_y(
#    5253         "x", x, y1, y2,
#    5254         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\axes\_axes.py:5238, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5234         pts = pts[:, ::-1]
#    5236     polys.append(pts)
# -> 5238 collection = mcoll.PolyCollection(polys, **kwargs)
#    5240 # now update the datalim and autoscale
#    5241 pts = np.row_stack([np.column_stack([ind[where], dep1[where]]),
#    5242                     np.column_stack([ind[where], dep2[where]])])
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\collections.py:1187, in PolyCollection.__init__(self, verts, sizes, closed, **kwargs)
#    1167 def __init__(self, verts, sizes=None, closed=True, **kwargs):
#    1168     """
#    1169     Parameters
#    1170     ----------
#    (...)
#    1185         Forwarded to `.Collection`.
#    1186     """
# -> 1187     super().__init__(**kwargs)
#    1188     self.set_sizes(sizes)
#    1189     self.set_verts(verts, closed)
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\collections.py:221, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     218 self._transOffset = transOffset
#     220 self._path_effects = None
# --> 221 self.update(kwargs)
#     222 self._paths = None
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\artist.py:1066, in Artist.update(self, props)
#    1063             if not callable(func):
#    1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
# -> 1066             ret.append(func(v))
#    1067 if ret:
#    1068     self.pchanged()
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\collections.py:741, in Collection.set_color(self, c)
#     728 def set_color(self, c):
#     729     """
#     730     Set both the edgecolor and the facecolor.
#     731
#    (...)
#     739         For setting the edge or face color individually.
#     740     """
# --> 741     self.set_facecolor(c)
#     742     self.set_edgecolor(c)
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\collections.py:770, in Collection.set_facecolor(self, c)
#     768     c = c.lower()
#     769 self._original_facecolor = c
# --> 770 self._set_facecolor(c)
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\collections.py:752, in Collection._set_facecolor(self, c)
#     749 if c is None:
#     750     c = self._get_default_facecolor()
# --> 752 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     753 self.stale = True
#
# File c:\Users\vince\miniconda3\lib\site-packages\matplotlib\colors.py:359, in to_rgba_array(c, alpha)
#     356     pass
#     358 if isinstance(c, str):
# --> 359     raise ValueError("Using a string of single character colors as "
#     360                      "a color sequence is not supported. The colors can "
#     361                      "be passed as an explicit list instead.")
#     363 if len(c) == 0:
#     364     return np.zeros((0, 4), float)
#
# ValueError: Using a string of single character colors as a color sequence is not supported. The colors can be passed as an explicit list instead.

# %% [markdown]
# ## The Final Viz

# %%
team_order = data[['team']].drop_duplicates().sort_values(by='team')
team_order = team_order['team'].to_list()

# %%
# Had to do this manually :(
team_logos = [
    8524, 9857, 7801, 8534,
    8535, 8636, 9885, 8543,
    9888, 8564, 6504, 9875,
    8686, 6480, 9882, 7943,
    9881, 9804, 8600, 9876
]

# %%
layout = '''
    ABCDE
    AFGHI
    AJKLM
    ANOPQ
    ARSTU
'''

fig = plt.figure(figsize=(18,8), dpi=300)
ax_dict = fig.subplot_mosaic(layout, gridspec_kw={'wspace':-0.45})

counter = 0
for k, ax in ax_dict.items():
    if k == 'A':
        continue
    team_id = data[data['team'] == team_order[counter]]['team_id'].iloc[0]
    plot_zone_dominance(ax, team_id)
    counter += 1

# We add the logos once we've reshaped the figure
counter = 0
for k, ax in ax_dict.items():
    if k == 'A':
        continue
    DC_to_FC = ax.transData.transform
    FC_to_NFC = fig.transFigure.inverted().transform
    # -- Take data coordinates and transform them to normalized figure coordinates
    DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
    ax_coords = DC_to_NFC((65,71))
    ax_size = 0.023
    image_ax = fig.add_axes(
        [ax_coords[0], ax_coords[1], ax_size, ax_size],
        fc='None'
    )
    fotmob_url = 'https://images.fotmob.com/image_resources/logo/teamlogo/'
    club_icon = Image.open(urllib.request.urlopen(f'{fotmob_url}{team_logos[counter]:.0f}.png'))
    image_ax.imshow(club_icon)
    image_ax.axis('off')
    counter += 1

# Chart Legend and Title
ax_dict['A'].set_xlim(0,1)
ax_dict['A'].set_ylim(0,1)

ax_dict['A'].annotate(
    xy=(.01,.95),
    text='SERIE A\nZONE CONTESE',
    ha='left',
    va='center',
    weight='bold',
    size=20
)

ax_dict['A'].plot(
    [.01,.7],
    [.88, .88],
    color='grey'
)

string_label = '''
<In quali zone del campo le squadre toccano>
<il pallone più dei loro avversari in open play?>

Le zone etichettate in  <VERDE>  indicano che
<la squadra> ottiene più del 55% dei tocchi totali.

Le zone etichettate in  <VIOLA>  indicano che
<la squadra avversaria> ottiene più del 55% dei 
tocchi totali, mentre le altre sono 
considerate  <CONTESE>.

<open play>: le azioni classiche di gioco e non
i calci piazzati o palle inattive.
'''

bbox_pad = 1.5
bboxprops = {'linewidth': 0, 'pad': bbox_pad}

ax_text(
    x=.01, y=.84,
    s=string_label,
    highlight_textprops=[
        {'weight':'bold'},
        {'weight':'bold'},
        {'color': 'w', 'weight': 'bold', 'bbox': {'facecolor':'#117733', **bboxprops}},
        {'weight':'bold'},
        {'color': 'w', 'weight': 'bold', 'bbox': {'facecolor':'#882255', **bboxprops}},
        {'weight':'bold'},
        {'color': 'black', 'weight': 'bold', 'bbox': {'facecolor':'#84184E', **bboxprops}},
        {'weight':'bold'}
    ],
    fontname="Nippo",
    ax=ax_dict['A']
)

ax_dict['A'].set_axis_off()

plt.savefig(
	"figures/10242022_seriea_zones.png",
	dpi = 600,
	facecolor = "#EFE9E6",
	bbox_inches="tight",
    edgecolor="none",
	transparent = False
)

plt.savefig(
	"figures/10242022_seriea_zones_tr.png",
	dpi = 600,
	facecolor = "none",
	bbox_inches="tight",
    edgecolor="none",
	transparent = True
)
