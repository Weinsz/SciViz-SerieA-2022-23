# %%
import ScraperFC as sfc
import traceback

# %%
import ScraperFC as sfc
import traceback

# Initialize the FBRef scraper
scraper = sfc.FBRef()
try:
    # Scrape the 
    scraper.
    lg_table = scraper.scrape_league_table(year=2023, league='Serie A')
except:
    # Catch and print any exceptions. This allows us to still close the
    # scraper below, even if an exception occurs.
    traceback.print_exc()
finally:
    # It's important to close the scraper when you're done with it. Otherwise,
    # you'll have a bunch of webdrivers open and running in the background.
    scraper.close()
# Out:
# Scraping 2023 Serie A league table

# %%
lg_table.loc[0:3]
# Questo ritorna le prime 4 posizione nella classifica di SERIE A
# Out:
#    Rk   Squad  MP   W  D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  \
# 0   1  Napoli  28  23  2   3  64  20  44   71    2.54  51.7  23.7  28.0
# 1   2   Lazio  28  16  7   5  44  19  25   55    1.96  35.3  30.5   4.8
# 2   3   Milan  28  15  6   7  48  36  12   51    1.82  43.6  31.6  12.0
# 3   4   Inter  28  16  2  10  47  32  15   50    1.79  50.1  25.3  24.8
#
#    xGD/90     Last 5  Attendance                     Top Team Scorer  \
# 0    1.00  W L W W L       27495                 Victor Osimhen - 21
# 1    0.17  W W D W W       26250  Ciro Immobile, Mattia Zaccagni - 9
# 2    0.43  W L D L W       50412                    Rafael Leão - 10
# 3    0.88  L W L L L       43384               Lautaro Martínez - 14
#
#            Goalkeeper  Notes
# 0          Alex Meret    NaN
# 1       Ivan Provedel    NaN
# 2  Ciprian Tătărușanu    NaN
# 3         André Onana    NaN

# %%
import ScraperFC as sfc
import traceback

# Initialize the Understat scraper
scraper = sfc.Understat()
try:
    # Scrape the table
    lg_table = scraper.scrape_league_table(year=2023, league="Serie A")
    #formations = scraper.scrape_formations(year=2023, league="Serie A")

except:
    # Catch and print any exceptions. This allows us to still close the
    # scraper below, even if an exception occurs.
    traceback.print_exc()
finally:
    # It"s important to close the scraper when you"re done with it. Otherwise,
    # you"ll have a bunch of webdrivers open and running in the background.
    scraper.close()

lg_table
# Out:
#      №         Team   M   W   D   L   G  GA  PTS     xG   NPxG    xGA  NPxGA  \
# 0    1       Napoli  28  23   2   3  64  20   71  57.54  52.22   24.1  22.57
# 1    2     Juventus  28  18   5   5  46  22   59  44.97  41.05  27.55  26.02
# 2    3        Lazio  28  16   7   5  44  19   55   37.9  33.20  31.73  30.97
# 3    4     AC Milan  28  15   6   7  48  36   51  51.87  49.59  31.69  27.89
# 4    5        Inter  28  16   2  10  47  32   50  53.12  49.32   25.0  22.71
# 5    6         Roma  28  15   5   8  38  26   50  49.44  44.11  21.88  20.35
# 6    7     Atalanta  28  14   6   8  47  32   48  47.98  41.73  31.17  29.65
# 7    8   Fiorentina  28  11   7  10  33  31   40  39.68  35.88  38.82  36.54
# 8    9      Bologna  28  11   7  10  36  36   40   31.5  28.45  41.38  36.05
# 9   10      Udinese  28   9  11   8  37  34   38  37.38  37.38  36.96  33.91
# 10  11       Torino  27  10   7  10  29  33   37   32.9  31.37  31.44  27.63
# 11  12     Sassuolo  27  10   6  11  35  40   36  35.84  30.51  37.24  34.19
# 12  13        Monza  28   9   7  12  32  39   34  33.01  29.96  39.73  39.73
# 13  14       Empoli  27   6  10  11  24  36   28  27.06  27.06  48.71  45.67
# 14  15  Salernitana  28   6  10  12  32  48   28  27.83  27.06  54.63  46.40
# 15  16        Lecce  27   6   9  12  24  32   27  24.63  23.10  32.47  29.43
# 16  17       Spezia  28   5  10  13  24  44   25  28.88  25.84  50.43  46.62
# 17  18       Verona  28   4   7  17  22  42   19  29.37  29.37   38.2  37.44
# 18  19    Sampdoria  28   3   6  19  16  47   15  24.55  23.02  47.17  40.32
# 19  20    Cremonese  28   1  10  17  23  52   13  28.06  23.30  53.23  49.42
#
#     NPxGD   PPDA  OPPDA   DC  ODC   xPTS
# 0   29.64  10.01  15.83  255  135  60.26
# 1   15.02  13.01  12.24  144  145  49.38
# 2    2.23  14.54  13.75  196  146  41.64
# 3   21.70   9.57  12.29  192  155  50.85
# 4   26.60   9.95  16.73  254  130   57.8
# 5   23.75  12.36  10.41  171  109  54.33
# 6   12.08  11.08  12.37  240  151  49.44
# 7   -0.66   8.80  11.66  225  138  38.05
# 8   -7.60  10.01  13.00  128  163  33.24
# 9    3.47  12.39  10.13  219  183  39.64
# 10   3.74  11.06  12.99  150  135  37.63
# 11  -3.68  14.54  10.49  167  197  36.83
# 12  -9.77  11.10  12.70  169  191  35.75
# 13 -18.61  12.34   9.98  132  211  24.81
# 14 -19.34  14.27  10.32  106  212  23.97
# 15  -6.32  10.63   8.08   91  180  31.95
# 16 -20.79  10.87   9.87  146  210  24.65
# 17  -8.07  10.90   8.67  132  200  32.63
# 18 -17.30  11.46   8.98  149  208  23.91
# 19 -26.12  12.44   9.78  148  215  23.68

# %%
print("Differenza reti esclusi i rigori")
lg_table.loc[0:3, 'NPxGD']
# Out:
# Differenza reti esclusi i rigori
# 0    31.12
# 1    13.80
# 2     3.28
# 3    24.78
# Name: NPxGD, dtype: float64

# %%
formations['Napoli']['4-3-3']
# Out:
# Formation    4-3-3
# Min           2191
# Sh             375
# G               58
# ShA            229
# GA              14
# xG           49.29
# xGA          19.59
# xGD           29.7
# xG90          2.02
# xGA90          0.8
# Name: 0, dtype: object

# %%
import ScraperFC as sfc
import traceback

# Initialize the Understat scraper
scraper = sfc.Understat()
try:
    # Scrape the table
    samp_vs_napoli = scraper.scrape_match("https://understat.com/match/18750")

except:
    # Catch and print any exceptions. This allows us to still close the
    # scraper below, even if an exception occurs.
    traceback.print_exc()
finally:
    # It"s important to close the scraper when you"re done with it. Otherwise,
    # you"ll have a bunch of webdrivers open and running in the background.
    scraper.close()

samp_vs_napoli
# Out:
#       id        date                                              shots  \
# 0  18750  2023-01-08          id  minute       result               ...
#
#    home team away team home win proba draw proba away win proba home goals  \
# 0  Sampdoria    Napoli            1.0        3.0           96.0        0.0
#
#   away goals  ... home SoT away SoT home DEEP away DEEP home PPDA away PPDA  \
# 0        2.0  ...      2.0      8.0       2.0      16.0      16.9      8.14
#
#   home xPTS away xPTS                                  home player stats  \
# 0      0.05      2.92          id goals own_goals shots              ...
#
#                                    away player stats
# 0          id goals own_goals shots              ...
#
# [1 rows x 24 columns]

# %%
samp_vs_napoli['away xPTS']
# Out:
# 0    2.92
# Name: away xPTS, dtype: object

# %%
import ScraperFC as sfc
import traceback

scraper = sfc.FiveThirtyEight()
try:
    testing = scraper.scrape_matches(year=2023, league='Serie A', save=True)
except:
    # Catch and print any exceptions. This allows us to still close the
    # scraper below, even if an exception occurs.
    traceback.print_exc()
finally:
    scraper.close()

testing
# Out:
# Traceback (most recent call last):
#   File "C:\Users\vince\AppData\Local\Temp\ipykernel_32292\832941356.py", line 6, in <module>
#     testing = scraper.scrape_matches(year=2023, league='Serie A', save=True)
#   File "c:\Users\vince\miniconda3\lib\site-packages\ScraperFC\FiveThirtyEight.py", line 87, in scrape_matches
#     time.sleep(1)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 14
#      11 finally:
#      12     scraper.close()
# ---> 14 testing
#
# NameError: name 'testing' is not defined

# %%
import ScraperFC as sfc
import traceback

# Initialize the Understat scraper
scraper = sfc.Capology()
try:
    # Scrape the table
    #payrolls = scraper.scrape_payrolls(year=2023, league="Serie A", currency="eur")
    salaries = scraper.scrape_salaries(year=2023, league="Serie A", currency="eur")
except:
    # Catch and print any exceptions. This allows us to still close the
    # scraper below, even if an exception occurs.
    traceback.print_exc()
finally:
    # It"s important to close the scraper when you"re done with it. Otherwise,
    # you"ll have a bunch of webdrivers open and running in the background.
    scraper.close()

salaries
# Out:
# Traceback (most recent call last):
#   File "C:\Users\vince\AppData\Local\Temp\ipykernel_32292\490819295.py", line 9, in <module>
#     salaries = scraper.scrape_salaries(year=2023, league="Serie A", currency="eur")
#   File "c:\Users\vince\miniconda3\lib\site-packages\ScraperFC\Capology.py", line 123, in scrape_salaries
#     df.columns = [
#   File "c:\Users\vince\miniconda3\lib\site-packages\pandas\core\generic.py", line 5596, in __setattr__
#     return object.__setattr__(self, name, value)
#   File "pandas\_libs\properties.pyx", line 70, in pandas._libs.properties.AxisProperty.__set__
#   File "c:\Users\vince\miniconda3\lib\site-packages\pandas\core\generic.py", line 769, in _set_axis
#     self._mgr.set_axis(axis, labels)
#   File "c:\Users\vince\miniconda3\lib\site-packages\pandas\core\internals\managers.py", line 214, in set_axis
#     self._validate_set_axis(axis, new_labels)
#   File "c:\Users\vince\miniconda3\lib\site-packages\pandas\core\internals\base.py", line 69, in _validate_set_axis
#     raise ValueError(
# ValueError: Length mismatch: Expected axis has 17 elements, new values have 8 elements
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 19
#      14 finally:
#      15     # It"s important to close the scraper when you"re done with it. Otherwise,
#      16     # you"ll have a bunch of webdrivers open and running in the background.
#      17     scraper.close()
# ---> 19 salaries
#
# NameError: name 'salaries' is not defined
